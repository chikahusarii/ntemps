# %% [markdown]
# ## **JOSS GANDOS**

# %%
#@title CEK GPU

from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 14519093205778821448, name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 9550168064
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 7405888235746650159
#  physical_device_desc: "device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5"]

# %%
#@title MOD GPU COY

from numba import jit, cuda
import numpy as np
# to measure exec time
from timeit import default_timer as timer

# normal function to run on cpu
def func(a):								
	for i in range(10000000):
		a[i]+= 1	

						
def func2(a):
	for i in range(10000000):
		a[i]+= 1
if __name__=="__main__":
	n = 10000000							
	a = np.ones(n, dtype = np.float64)
	b = np.ones(n, dtype = np.float32)
	
	start = timer()
	func(a)
	print("without GPU:", timer()-start)	
	
	start = timer()
	func2(a)
	print("with GPU:", timer()-start)
# Out:
# without GPU: 5.160078757000008
# with GPU: 5.049328731999992

# %%
#@title TUNNEL ANYAR

# !wget -nc https://github.com/tmate-io/tmate/releases/download/2.4.0/tmate-2.4.0-static-linux-i386.tar.xz &> /dev/null
# !tar --skip-old-files -xvf tmate-2.4.0-static-linux-i386.tar.xz &> /dev/null
# !rm -f nohup.out; bash -ic 'nohup ./tmate-2.4.0-static-linux-i386/tmate -S /tmp/tmate.sock new-session -d & disown -a' >/dev/null 2>&1
# !./tmate-2.4.0-static-linux-i386/tmate -S /tmp/tmate.sock wait tmate-ready
# !./tmate-2.4.0-static-linux-i386/tmate -S /tmp/tmate.sock display -p "Connect with SSH address: #{tmate_ssh}"
# !./tmate-2.4.0-static-linux-i386/tmate -S /tmp/tmate.sock display -p "Connect with web: #{tmate_web}"
# Out:
# Connect with SSH address: ssh HHLnpMwE4znfeP3td2dWQvsDQ@nyc1.tmate.io
# Connect with web: https://tmate.io/t/HHLnpMwE4znfeP3td2dWQvsDQ

# %%
#@title **Skip >>>**

import time
def infy():
    i = 0
    while True:
        yield i
        i += 1
        time.sleep(5)

for x in infy():
  product1=4
  product2=9
  product3=2
  product4=1
  product5=5
  total=product1+product2+product3+product4+product5
  print("Total ",total)
print(x)
# Out:
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
# Total  21
